669617632036), (971, 0.08518629619168604), (778, 0.08503945373665975), (2475, 0.08429299699419188), (3272, 0.08409651426267442), (493, 0.08350857324158026), (1081, 0.08314457071039846), (2369, 0.0830300241251834), (1423, 0.08278599565622166), (785, 0.08250849747832761), (3837, 0.08223334396720679), (972, 0.08167671138461466), (2197, 0.08159761291332415), (4551, 0.08109479047161929), (1147, 0.08105011232406684), (1847, 0.08098285463602128), (2044, 0.08097480308646446), (1469, 0.08094768523447791), (1806, 0.08051971423066144), (268, 0.08046457313209551), (1719, 0.08044837132712), (60, 0.08041046327047027), (3734, 0.08030098843938281), (30, 0.07998129952146046), (3499, 0.07986116295308006), (2554, 0.07982776811051352), (2904, 0.07965502226264591), (2560, 0.07933178554574097), (3145, 0.07924797488684626), (2760, 0.07906943034919531), (703, 0.07893496924800114), (2769, 0.07893390518098102), (637, 0.07886670068110771), (226, 0.07859031606949678), (2366, 0.07858910246666495), (3791, 0.07825030008530563), (2455, 0.078136275 ...

# %%
# print the name of similar movies based on the index

print('Movies suggested for you : \n')

i = 1

for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index==index]['title'].values[0]
  if (i<30):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Movies suggested for you :
#
# 1 . Iris
# 2 . Notes on a Scandal
# 3 . Cry Freedom
# 4 . Shakespeare in Love
# 5 . Sense and Sensibility
# 6 . My Week with Marilyn
# 7 . Match Point
# 8 . Autumn in New York
# 9 . Brooklyn
# 10 . My Best Friend's Wedding
# 11 . The Second Best Exotic Marigold Hotel
# 12 . Down to You
# 13 . The Shipping News
# 14 . Beastly
# 15 . The Best Exotic Marigold Hotel
# 16 . Something Borrowed
# 17 . The Importance of Being Earnest
# 18 . Insurgent
# 19 . Moulin Rouge!
# 20 . Dear John
# 21 . Serendipity
# 22 . Chasing Amy
# 23 . The Young Victoria
# 24 . Tea with Mussolini
# 25 . You, Me and Dupree
# 26 . Return to Me
# 27 . Skyfall
# 28 . Mrs Henderson Presents
# 29 . Bridget Jones: The Edge of Reason

# %% [markdown]
# Movie Recommendation Sytem

# %%
movie_name = input(' Enter your favourite movie name : ')

list_of_all_titles = movies_data['title'].tolist()

find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)

close_match = find_close_match[0]

index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]

similarity_score = list(enumerate(similarity[index_of_the_movie]))

sorted_similar_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True)

print('Movies suggested for you : \n')

i = 1

for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index==index]['title'].values[0]
  if (i<30):
    print(i, '.',title_from_index)
    i+=1
# Out:
#  Enter your favourite movie name : Robin Hood
# Movies suggested for you :
#
# 1 . Robin Hood
# 2 . Gladiator
# 3 . Body of Lies
# 4 . Seventh Son
# 5 . Minority Report
# 6 . The Hunger Games
# 7 . Rush Hour 3
# 8 . What Dreams May Come
# 9 . In the Name of the King: A Dungeon Siege Tale
# 10 . Conan the Barbarian
# 11 . The Exorcist
# 12 . The Greatest Story Ever Told
# 13 . Winter's Tale
# 14 . The Talented Mr. Ripley
# 15 . State of Play
# 16 . The Lazarus Effect
# 17 . Bandits
# 18 . American Gangster
# 19 . Kingdom of Heaven
# 20 . Flash Gordon
# 21 . Extremely Loud & Incredibly Close
# 22 . Indiana Jones and the Kingdom of the Crystal Skull
# 23 . Exorcist II: The Heretic
# 24 . Tuck Everlasting
# 25 . G.I. Jane
# 26 . Defendor
# 27 . Flight of the Phoenix
# 28 . The Yellow Handkerchief
# 29 . The Night Visitor

# %%
import pandas as pd
import json

# Load the dataset
movies_csv_path = "movies.csv"  # Ensure the CSV file is in the same directory
movies_data = pd.read_csv(movies_csv_path)

# Selecting relevant features
selected_features = ['genres', 'keywords', 'tagline', 'cast', 'director']

# Filling null values with an empty string
for feature in selected_features:
    movies_data[feature] = movies_data[feature].fillna('')

# Combining features into a single string
movies_data["combined_features"] = movies_data[selected_features].agg(' '.join, axis=1)

# Creating JSON format with relevant columns
json_data = movies_data[['title', 'combined_features']].to_dict(orient='records')

# Save JSON file
json_file_path = "movies_data.json"
with open(json_file_path, "w", encoding="utf-8") as json_file:
    json.dump(json_data, json_file, indent=4)

print(f"Movies data saved to {json_file_path}")
# Out:
# Movies data saved to movies_data.json
